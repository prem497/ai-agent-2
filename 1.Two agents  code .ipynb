# %%
import autogen
autogen.__version__
# Out:
# C:\Users\premchandar\anaconda3\envs\autogen_env\lib\site-packages\flaml\__init__.py:20: UserWarning: flaml.automl is not available. Please install flaml[automl] to enable AutoML functionalities.
#   warnings.warn("flaml.automl is not available. Please install flaml[automl] to enable AutoML functionalities.")
# C:\Users\premchandar\anaconda3\envs\autogen_env\lib\site-packages\google\api_core\_python_version_support.py:273: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# '0.2.35'

# %%
#!pip install autogen-agentchat[gemini]~=0.2
#!pip install ag2[gemini]
#!pip install chromadb==0.5.1
#!pip install google-generativeai == 0.8.4
#!pip install vertexai == 1.71.1
#ag2 ==0.7.3
#autogen-agentchat ==  0.4.3
#python  3.11.11

# %%
import agentops
agentops.init("AIzaSyB5CXDojjuqtRZKQw-jORr5KjNIQmgMAuo")

# %%
from pathlib import Path

from autogen import ConversableAgent
from autogen.coding import  CodeBlock, LocalCommandLineCodeExecutor
work_dir = Path("coding")
work_dir.mkdir(exist_ok=True)

executor = LocalCommandLineCodeExecutor(work_dir=work_dir)

#Agent 1
code_executor_agent = ConversableAgent(
    name="code_executor_agent",
    llm_config=False,
    code_execution_config={
        "executor": executor,
    },
    human_input_mode="NEVER",
)

# %%
from autogen import ConversableAgent
import os

os.environ["GOOGLE_API_KEY"] = "AIzaSyBvbeecbH13CKu63Qifd_fyJZqTJxk5GkY"

code_writer_agent = ConversableAgent(
    name="code_writer",
    system_message=code_writer_system_message,
    llm_config={
        "config_list": [
            {
                "model": "gemini-1.5-pro",
                "api_key": os.environ["AIzaSyBvbeecbH13CKu63Qifd_fyJZqTJxk5GkY"],
                "api_type": "google"
            }
        ]
    },
    code_execution_config=False,
    max_consecutive_auto_reply=2,
    human_input_mode="NEVER"
)
print("Agent created successfully")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       2 import os
#       4 os.environ["GOOGLE_API_KEY"] = "AIzaSyBvbeecbH13CKu63Qifd_fyJZqTJxk5GkY"
# ----> 6 code_writer_agent = ConversableAgent(
#       7     name="code_writer",
#       8     system_message=code_writer_system_message,
#       9     llm_config={
#      10         "config_list": [
#      11             {
#      12                 "model": "gemini-1.5-pro",
#      13                 "api_key": os.environ["AIzaSyBvbeecbH13CKu63Qifd_fyJZqTJxk5GkY"],
#      14                 "api_type": "google"
#      15             }
#      16         ]
#      17     },
#      18     code_execution_config=False,
#      19     max_consecutive_auto_reply=2,
#      20     human_input_mode="NEVER"
#      21 )
#      22 print("Agent created successfully")
#
# NameError: name 'ConversableAgent' is not defined
